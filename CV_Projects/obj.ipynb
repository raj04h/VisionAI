# %%
import cv2
from ultralytics import YOLO

from openvino.runtime import Core
import cv2
import numpy as np
# Out:
# d:\Program_file\Anaconda\Lib\site-packages\openvino\runtime\__init__.py:10: DeprecationWarning: The `openvino.runtime` module is deprecated and will be removed in the 2026.0 release. Please replace `openvino.runtime` with `openvino`.
#   warnings.warn(

# %%
# Load pretrained YOLO model
model = YOLO("yolov8n.pt")

# Export to OpenVINO
model.export(format="openvino")
# Out:
# Ultralytics 8.3.189  Python-3.13.5 torch-2.8.0+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# OpenVINO: starting export with openvino 2025.2.0-19140-c01cd93e24d-releases/2025/2...
# OpenVINO: export success  2.8s, saved as 'yolov8n_openvino_model\' (12.3 MB)
#
# Export complete (3.1s)
# Results saved to D:\CS_code\Dev_Corner\AI_DEV\CV _code\CV_Projects
# Predict:         yolo predict task=detect model=yolov8n_openvino_model imgsz=640
# Validate:        yolo val task=detect model=yolov8n_openvino_model imgsz=640 data=coco.yaml
# Visualize:       https://netron.app
# 'yolov8n_openvino_model'

# %%
# Initialize OpenVINO core
ie = Core()

# List available devices
print("Available devices:", ie.available_devices)
# Out:
# Available devices: ['CPU', 'GPU.0', 'GPU.1']

# %%
# Load compiled model on Intel GPU (try "GPU.0" or "GPU.1")
model_path = r"D:\CS_code\Dev_Corner\AI_DEV\CV _code\CV_Projects\yolov8n_openvino_model\yolov8n.xml"
compiled_model = ie.compile_model(model_path, "AUTO")

# %%
input_layer = compiled_model.input(0)
output_layer = compiled_model.output(0)

# Webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Preprocess
    resized = cv2.resize(frame, (640, 640))
    blob = resized.transpose(2, 0, 1)[None].astype("float32") / 255.0

    # Run inference
    results = compiled_model([blob])[output_layer]
    
        # Results shape: (1, N, 84) → (batch, boxes, [x,y,w,h,conf + 80 classes])
    preds = results[0]

    # Get boxes, scores, class IDs
    boxes = preds[:, :4]
    scores = preds[:, 4:5]
    class_probs = preds[:, 5:]
    class_ids = class_probs.argmax(axis=1)
    confidences = scores.flatten() * class_probs.max(axis=1)

    # Filter out low-confidence detections
    conf_threshold = 0.3
    mask = confidences > conf_threshold
    boxes = boxes[mask]
    confidences = confidences[mask]
    class_ids = class_ids[mask]

    # Convert from (cx,cy,w,h) to (x1,y1,x2,y2) in original frame scale
    h, w = frame.shape[:2]
    scale_x, scale_y = w / 640, h / 640

    for box, score, cls in zip(boxes, confidences, class_ids):
        cx, cy, bw, bh = box
        x1 = int((cx - bw / 2) * scale_x)
        y1 = int((cy - bh / 2) * scale_y)
        x2 = int((cx + bw / 2) * scale_x)
        y2 = int((cy + bh / 2) * scale_y)

        # Draw bounding box
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f"cls {int(cls)} {score:.2f}", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    # (this part needs implementing)

    cv2.imshow("OpenVINO YOLOv8", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       5 cap = cv2.VideoCapture(0)
#       7 while True:
# ----> 8     ret, frame = cap.read()
#       9     if not ret:
#      10         break
#
# KeyboardInterrupt:

# %%
# Open webcam
cap = cv2.VideoCapture(1)
if not cap.isOpened():
    print("Error: Cannot access camera")
    exit()

prev_gray = None  # for motion detection

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Convert to grayscale for motion detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (21, 21), 0)

    motion_detected = False
    if prev_gray is not None:
        frame_delta = cv2.absdiff(prev_gray, gray)
        thresh = cv2.threshold(frame_delta, 25, 255, cv2.THRESH_BINARY)[1]
        motion_detected = cv2.countNonZero(thresh) > 5000  # adjust sensitivity
    prev_gray = gray

    # Run YOLO object + pose detection if motion is detected
    if motion_detected:
        # Object detection
        results = obj_model(frame, stream=True)
        for r in results:
            for box in r.boxes:
                x1, y1, x2, y2 = box.xyxy[0].int().tolist()
                conf = float(box.conf[0])
                cls = int(box.cls[0])
                label = obj_model.names[cls]

                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, f"{label} {conf:.2f}", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

        # Pose detection
        pose_results = pose_model(frame, stream=True)
        for r in pose_results:
            if r.keypoints is not None:
                kps = r.keypoints.xy.int().tolist()  # [num_people][num_keypoints][2]
                for person in kps:                  # loop over each detected person
                    for x, y in person:             # loop over keypoints
                        cv2.circle(frame, (x, y), 4, (0, 0, 255), -1)

    # Label motion state
    status = "Motion Detected" if motion_detected else "No Motion"
    cv2.putText(frame, status, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1,
                (0, 0, 255) if motion_detected else (200, 200, 200), 2)

    # Show the frame
    cv2.imshow("YOLOv11 Motion + Object + Pose", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 78.2ms
# Speed: 3.0ms preprocess, 78.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 54.7ms
# Speed: 2.0ms preprocess, 54.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.6ms
# Speed: 2.8ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.5ms
# Speed: 1.9ms preprocess, 52.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.1ms
# Speed: 2.0ms preprocess, 52.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.7ms
# Speed: 2.3ms preprocess, 43.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.3ms
# Speed: 1.5ms preprocess, 46.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 1.9ms preprocess, 47.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.4ms
# Speed: 1.8ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 1.6ms preprocess, 46.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.3ms
# Speed: 2.8ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.3ms
# Speed: 1.5ms preprocess, 49.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.2ms
# Speed: 1.4ms preprocess, 51.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.1ms
# Speed: 1.4ms preprocess, 49.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.2ms
# Speed: 1.5ms preprocess, 48.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 1.7ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.2ms
# Speed: 1.5ms preprocess, 66.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.4ms preprocess, 46.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.9ms
# Speed: 1.3ms preprocess, 47.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.7ms
# Speed: 1.4ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.6ms
# Speed: 1.5ms preprocess, 47.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.9ms
# Speed: 2.0ms preprocess, 44.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.9ms
# Speed: 1.7ms preprocess, 45.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.7ms
# Speed: 2.0ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.7ms
# Speed: 1.6ms preprocess, 45.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.8ms
# Speed: 1.3ms preprocess, 45.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.1ms
# Speed: 1.4ms preprocess, 42.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.1ms
# Speed: 1.9ms preprocess, 44.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.4ms
# Speed: 1.7ms preprocess, 64.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.8ms
# Speed: 1.7ms preprocess, 47.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 51.5ms
# Speed: 1.7ms preprocess, 51.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.8ms
# Speed: 1.5ms preprocess, 47.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.5ms
# Speed: 1.5ms preprocess, 47.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 1.5ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.6ms
# Speed: 1.7ms preprocess, 49.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.3ms
# Speed: 1.6ms preprocess, 47.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.8ms
# Speed: 1.4ms preprocess, 45.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.4ms
# Speed: 1.5ms preprocess, 45.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tie, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.5ms
# Speed: 1.6ms preprocess, 47.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.5ms
# Speed: 1.7ms preprocess, 53.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.9ms
# Speed: 1.6ms preprocess, 50.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 40.6ms
# Speed: 1.4ms preprocess, 40.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.1ms
# Speed: 1.8ms preprocess, 47.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.4ms
# Speed: 1.5ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.1ms
# Speed: 1.6ms preprocess, 47.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.5ms
# Speed: 1.5ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.5ms
# Speed: 1.5ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.1ms
# Speed: 1.6ms preprocess, 46.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.4ms
# Speed: 1.5ms preprocess, 42.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.8ms
# Speed: 1.7ms preprocess, 44.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.9ms
# Speed: 1.7ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 63.8ms
# Speed: 1.5ms preprocess, 63.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.8ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.9ms
# Speed: 1.6ms preprocess, 44.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.3ms
# Speed: 1.5ms preprocess, 46.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 1.4ms preprocess, 41.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.8ms
# Speed: 1.6ms preprocess, 44.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 1.9ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.6ms
# Speed: 1.5ms preprocess, 49.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.0ms
# Speed: 1.4ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.7ms
# Speed: 1.6ms preprocess, 43.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.7ms
# Speed: 1.7ms preprocess, 46.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 42.4ms
# Speed: 1.9ms preprocess, 42.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.4ms preprocess, 46.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 1 cat, 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.4ms
# Speed: 1.7ms preprocess, 45.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.7ms
# Speed: 1.4ms preprocess, 46.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.7ms
# Speed: 1.6ms preprocess, 45.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.5ms preprocess, 45.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 sink, 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.5ms
# Speed: 1.5ms preprocess, 71.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.7ms
# Speed: 1.4ms preprocess, 44.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.4ms preprocess, 46.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.5ms
# Speed: 1.4ms preprocess, 45.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.3ms
# Speed: 1.5ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.9ms
# Speed: 1.4ms preprocess, 41.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.7ms
# Speed: 1.3ms preprocess, 45.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bird, 44.0ms
# Speed: 1.6ms preprocess, 44.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.5ms
# Speed: 1.4ms preprocess, 46.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 1.4ms preprocess, 40.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.5ms
# Speed: 1.5ms preprocess, 43.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.1ms
# Speed: 1.5ms preprocess, 47.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.8ms
# Speed: 1.5ms preprocess, 46.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.5ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.4ms
# Speed: 1.7ms preprocess, 44.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.8ms
# Speed: 1.4ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.4ms
# Speed: 1.6ms preprocess, 60.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.6ms preprocess, 46.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.9ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.6ms
# Speed: 1.7ms preprocess, 46.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.7ms
# Speed: 1.5ms preprocess, 43.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 1.8ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.6ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.8ms preprocess, 45.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.6ms
# Speed: 1.7ms preprocess, 45.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 39.9ms
# Speed: 1.4ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.6ms
# Speed: 1.5ms preprocess, 46.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.9ms
# Speed: 1.7ms preprocess, 44.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.0ms
# Speed: 1.5ms preprocess, 45.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.6ms
# Speed: 1.7ms preprocess, 49.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 1.5ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 82.1ms
# Speed: 1.6ms preprocess, 82.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 2.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.0ms
# Speed: 1.7ms preprocess, 45.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.5ms
# Speed: 1.6ms preprocess, 47.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.1ms
# Speed: 1.5ms preprocess, 45.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.8ms
# Speed: 1.4ms preprocess, 45.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.8ms preprocess, 43.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.3ms
# Speed: 1.6ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.9ms
# Speed: 1.4ms preprocess, 47.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.8ms
# Speed: 1.7ms preprocess, 51.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.3ms
# Speed: 1.8ms preprocess, 47.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.5ms
# Speed: 1.6ms preprocess, 45.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 43.8ms
# Speed: 2.0ms preprocess, 43.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.7ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.5ms
# Speed: 1.6ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.0ms
# Speed: 1.5ms preprocess, 45.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 41.1ms
# Speed: 1.3ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.5ms
# Speed: 1.4ms preprocess, 45.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.2ms
# Speed: 1.6ms preprocess, 47.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.1ms
# Speed: 1.7ms preprocess, 47.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.2ms
# Speed: 1.5ms preprocess, 46.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.5ms
# Speed: 1.8ms preprocess, 43.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.5ms
# Speed: 1.5ms preprocess, 45.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.5ms
# Speed: 1.5ms preprocess, 48.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.7ms
# Speed: 1.6ms preprocess, 44.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 1.9ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.3ms
# Speed: 1.6ms preprocess, 46.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.9ms
# Speed: 1.5ms preprocess, 61.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.6ms
# Speed: 1.8ms preprocess, 57.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.9ms
# Speed: 1.8ms preprocess, 42.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.0ms
# Speed: 1.7ms preprocess, 45.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.3ms preprocess, 46.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.5ms
# Speed: 1.4ms preprocess, 45.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.8ms
# Speed: 1.4ms preprocess, 49.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.1ms
# Speed: 1.6ms preprocess, 46.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.1ms
# Speed: 1.4ms preprocess, 42.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.2ms
# Speed: 1.5ms preprocess, 45.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.6ms
# Speed: 1.3ms preprocess, 46.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 41.5ms
# Speed: 1.3ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.3ms
# Speed: 1.3ms preprocess, 48.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 42.4ms
# Speed: 1.5ms preprocess, 42.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.6ms
# Speed: 1.6ms preprocess, 44.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 64.1ms
# Speed: 1.7ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.2ms
# Speed: 1.6ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 birds, 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.4ms
# Speed: 1.4ms preprocess, 46.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 1 cat, 44.0ms
# Speed: 1.4ms preprocess, 44.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.9ms
# Speed: 1.3ms preprocess, 48.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 1.4ms preprocess, 46.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.6ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 suitcase, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.2ms
# Speed: 1.7ms preprocess, 47.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.2ms
# Speed: 1.6ms preprocess, 51.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 1.6ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.6ms preprocess, 45.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.4ms
# Speed: 1.5ms preprocess, 45.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.8ms
# Speed: 1.4ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.1ms
# Speed: 2.2ms preprocess, 48.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.1ms
# Speed: 1.6ms preprocess, 47.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.6ms preprocess, 54.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.5ms
# Speed: 1.7ms preprocess, 59.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.2ms
# Speed: 1.6ms preprocess, 47.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.9ms preprocess, 48.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.4ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 1 sink, 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 49.0ms
# Speed: 1.7ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.6ms
# Speed: 1.5ms preprocess, 44.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 43.0ms
# Speed: 1.8ms preprocess, 43.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.4ms preprocess, 46.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 1.5ms preprocess, 46.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.9ms
# Speed: 1.5ms preprocess, 47.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.4ms
# Speed: 1.6ms preprocess, 50.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.9ms
# Speed: 1.7ms preprocess, 67.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.0ms
# Speed: 1.8ms preprocess, 53.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.4ms
# Speed: 1.6ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.5ms preprocess, 46.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.8ms
# Speed: 1.5ms preprocess, 46.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 1.6ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 toilet, 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.5ms preprocess, 46.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 1.3ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 1.7ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.9ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms
# Speed: 1.4ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.3ms
# Speed: 1.3ms preprocess, 47.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.4ms preprocess, 48.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 1.6ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.6ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.5ms preprocess, 46.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.1ms
# Speed: 1.4ms preprocess, 65.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 39.4ms
# Speed: 1.4ms preprocess, 39.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.6ms
# Speed: 1.7ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.8ms
# Speed: 1.7ms preprocess, 44.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.9ms
# Speed: 1.8ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.9ms preprocess, 47.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 1.4ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.5ms
# Speed: 1.6ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 1.7ms preprocess, 48.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.8ms
# Speed: 1.7ms preprocess, 46.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 40.8ms
# Speed: 1.4ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 1.9ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.2ms
# Speed: 1.5ms preprocess, 53.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.8ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.5ms
# Speed: 1.8ms preprocess, 44.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.9ms
# Speed: 1.3ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.9ms
# Speed: 1.7ms preprocess, 64.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.7ms
# Speed: 1.6ms preprocess, 56.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.5ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.8ms
# Speed: 1.5ms preprocess, 47.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 41.5ms
# Speed: 1.7ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 1.7ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.8ms preprocess, 45.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 44.3ms
# Speed: 1.5ms preprocess, 44.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.3ms preprocess, 46.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.4ms
# Speed: 1.7ms preprocess, 46.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.8ms
# ...
#
# 0: 384x640 2 persons, 48.0ms
# Speed: 1.4ms preprocess, 48.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 47.5ms
# Speed: 1.5ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.0ms
# Speed: 1.3ms preprocess, 65.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 oven, 47.3ms
# Speed: 1.6ms preprocess, 47.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.2ms
# Speed: 1.4ms preprocess, 47.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 ovens, 44.6ms
# Speed: 1.5ms preprocess, 44.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.0ms
# Speed: 1.4ms preprocess, 45.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 45.3ms
# Speed: 1.5ms preprocess, 45.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 42.0ms
# Speed: 1.7ms preprocess, 42.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tie, 47.9ms
# Speed: 1.4ms preprocess, 47.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 50.9ms
# Speed: 1.7ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tie, 43.3ms
# Speed: 1.6ms preprocess, 43.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.1ms
# Speed: 1.5ms preprocess, 60.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 ties, 59.4ms
# Speed: 1.6ms preprocess, 59.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.7ms
# Speed: 1.5ms preprocess, 52.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 ties, 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 ties, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 ties, 47.5ms
# Speed: 1.6ms preprocess, 47.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.0ms
# Speed: 1.5ms preprocess, 48.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.6ms preprocess, 47.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tie, 49.1ms
# Speed: 1.3ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.9ms
# Speed: 1.5ms preprocess, 57.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 oven, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.6ms
# Speed: 1.4ms preprocess, 44.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.5ms preprocess, 46.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.4ms preprocess, 45.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.7ms preprocess, 48.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tie, 65.9ms
# Speed: 1.6ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.6ms preprocess, 52.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 1.8ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 1.7ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.9ms
# Speed: 1.3ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.6ms preprocess, 46.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 47.0ms
# Speed: 1.3ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.7ms preprocess, 45.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 43.5ms
# Speed: 1.3ms preprocess, 43.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.9ms
# Speed: 1.4ms preprocess, 50.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.4ms
# Speed: 1.4ms preprocess, 64.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.7ms preprocess, 55.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms
# Speed: 1.6ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.6ms preprocess, 46.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.3ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.3ms
# Speed: 1.6ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.4ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.4ms
# Speed: 1.7ms preprocess, 46.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.6ms preprocess, 48.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.3ms
# Speed: 1.7ms preprocess, 47.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.7ms
# Speed: 1.8ms preprocess, 63.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.1ms
# Speed: 1.3ms preprocess, 48.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 sink, 47.8ms
# Speed: 1.4ms preprocess, 47.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.5ms preprocess, 46.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.6ms
# Speed: 1.8ms preprocess, 44.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.6ms preprocess, 52.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.4ms
# Speed: 1.4ms preprocess, 58.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.3ms
# Speed: 1.7ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.0ms
# Speed: 1.8ms preprocess, 45.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.6ms
# Speed: 1.5ms preprocess, 57.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.3ms
# Speed: 1.7ms preprocess, 44.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.4ms
# Speed: 1.8ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.8ms
# Speed: 1.8ms preprocess, 48.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.7ms
# Speed: 1.5ms preprocess, 63.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.2ms
# Speed: 1.6ms preprocess, 55.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.9ms
# Speed: 1.4ms preprocess, 45.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.6ms
# Speed: 1.4ms preprocess, 46.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.0ms
# Speed: 1.4ms preprocess, 49.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.8ms
# Speed: 1.7ms preprocess, 42.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.4ms
# Speed: 1.4ms preprocess, 41.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.4ms
# Speed: 1.6ms preprocess, 46.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.3ms
# Speed: 1.5ms preprocess, 67.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 57.6ms
# Speed: 1.6ms preprocess, 57.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.5ms
# Speed: 1.5ms preprocess, 44.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.6ms
# Speed: 2.3ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.8ms
# Speed: 1.8ms preprocess, 47.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.9ms
# Speed: 1.4ms preprocess, 47.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.6ms
# Speed: 1.6ms preprocess, 43.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.5ms
# Speed: 1.5ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.1ms
# Speed: 1.4ms preprocess, 45.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.5ms
# Speed: 1.8ms preprocess, 46.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.7ms
# Speed: 1.4ms preprocess, 54.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.4ms
# Speed: 1.8ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.0ms
# Speed: 1.6ms preprocess, 45.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.4ms
# Speed: 1.5ms preprocess, 68.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.8ms
# Speed: 1.7ms preprocess, 59.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 handbag, 42.6ms
# Speed: 1.7ms preprocess, 42.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.7ms
# Speed: 1.4ms preprocess, 45.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
