# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix,ConfusionMatrixDisplay

# %%
data=pd.read_csv(r"D:\Data centr\Exel_data\int data\seattleWeather_1948-2017.csv")

# %%
data #/data.describe
# Out:
#              DATE  PRCP  TMAX  TMIN   RAIN
# 0      1948-01-01  0.47    51    42   True
# 1      1948-01-02  0.59    45    36   True
# 2      1948-01-03  0.42    45    35   True
# 3      1948-01-04  0.31    45    34   True
# 4      1948-01-05  0.17    45    32   True
# ...           ...   ...   ...   ...    ...
# 25546  2017-12-10  0.00    49    34  False
# 25547  2017-12-11  0.00    49    29  False
# 25548  2017-12-12  0.00    46    32  False
# 25549  2017-12-13  0.00    48    34  False
# 25550  2017-12-14  0.00    50    36  False
#
# [25551 rows x 5 columns]

# %%
data.shape
# Out:
# (25551, 5)

# %%
data.describe()
# Out:
#                PRCP          TMAX          TMIN
# count  25548.000000  25551.000000  25551.000000
# mean       0.106222     59.544206     44.514226
# std        0.239031     12.772984      8.892836
# min        0.000000      4.000000      0.000000
# 25%        0.000000     50.000000     38.000000
# 50%        0.000000     58.000000     45.000000
# 75%        0.100000     69.000000     52.000000
# max        5.020000    103.000000     71.000000

# %%
data.isnull().any()
# Out:
# DATE    False
# PRCP     True
# TMAX    False
# TMIN    False
# RAIN     True
# dtype: bool

# %%
features=["PRCP","TMAX","TMIN"]
x=data[features]
y=data.iloc[:,4]

# %%
x
# Out:
#        PRCP  TMAX  TMIN
# 0      0.47    51    42
# 1      0.59    45    36
# 2      0.42    45    35
# 3      0.31    45    34
# 4      0.17    45    32
# ...     ...   ...   ...
# 25546  0.00    49    34
# 25547  0.00    49    29
# 25548  0.00    46    32
# 25549  0.00    48    34
# 25550  0.00    50    36
#
# [25551 rows x 3 columns]

# %%
y
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 25546    False
# 25547    False
# 25548    False
# 25549    False
# 25550    False
# Name: RAIN, Length: 25551, dtype: object

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
len(x_train)
# Out:
# 7666

# %%
len(x_test)
# Out:
# 17885

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((7666, 3), (7666,), (17885, 3), (17885,))

# %%
model=GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 model.fit(x_train,y_train)
#
# File D:\program\conda\lib\site-packages\sklearn\naive_bayes.py:267, in GaussianNB.fit(self, X, y, sample_weight)
#     265 self._validate_params()
#     266 y = self._validate_data(y=y)
# --> 267 return self._partial_fit(
#     268     X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     269 )
#
# File D:\program\conda\lib\site-packages\sklearn\naive_bayes.py:427, in GaussianNB._partial_fit(self, X, y, classes, _refit, sample_weight)
#     424 if _refit:
#     425     self.classes_ = None
# --> 427 first_call = _check_partial_fit_first_call(self, classes)
#     428 X, y = self._validate_data(X, y, reset=first_call)
#     429 if sample_weight is not None:
#
# File D:\program\conda\lib\site-packages\sklearn\utils\multiclass.py:397, in _check_partial_fit_first_call(clf, classes)
#     390             raise ValueError(
#     391                 "`classes=%r` is not the same as on last call "
#     392                 "to partial_fit, was: %r" % (classes, clf.classes_)
#     393             )
#     395     else:
#     396         # This is the first call to partial_fit
# --> 397         clf.classes_ = unique_labels(classes)
#     398         return True
#     400 # classes is None and clf.classes_ has already previously been set:
#     401 # nothing to do
#
# File D:\program\conda\lib\site-packages\sklearn\utils\multiclass.py:107, in unique_labels(*ys)
#     105 _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     106 if not _unique_labels:
# --> 107     raise ValueError("Unknown label type: %s" % repr(ys))
#     109 if is_array_api:
#     110     # array_api does not allow for mixed dtypes
#     111     unique_ys = xp.concat([_unique_labels(y) for y in ys])
#
# ValueError: Unknown label type: (array([False, True], dtype=object),)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# ----------------------------------------------------------------
# NotFittedError                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 y_pred=model.predict(x_test)
#       2 y_pred
#
# File D:\program\conda\lib\site-packages\sklearn\naive_bayes.py:104, in _BaseNB.predict(self, X)
#      90 def predict(self, X):
#      91     """
#      92     Perform classification on an array of test vectors X.
#      93
#    (...)
#     102         Predicted target values for X.
#     103     """
# --> 104     check_is_fitted(self)
#     105     X = self._check_X(X)
#     106     jll = self._joint_log_likelihood(X)
#
# File D:\program\conda\lib\site-packages\sklearn\utils\validation.py:1390, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1385     fitted = [
#    1386         v for v in vars(estimator) if v.endswith("_") and not v.startswith("__")
#    1387     ]
#    1389 if not fitted:
# -> 1390     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This GaussianNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
print("train_accuracy: ",accuracy_score(y_train,model.predict(x_train)))
print("test_accuracy: ",accuracy_score(y_test,y_pred))
# Out:
# ----------------------------------------------------------------
# NotFittedError                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print("train_accuracy: ",accuracy_score(y_train,model.predict(x_train)))
#       2 print("test_accuracy: ",accuracy_score(y_test,y_pred))
#
# File D:\program\conda\lib\site-packages\sklearn\naive_bayes.py:104, in _BaseNB.predict(self, X)
#      90 def predict(self, X):
#      91     """
#      92     Perform classification on an array of test vectors X.
#      93
#    (...)
#     102         Predicted target values for X.
#     103     """
# --> 104     check_is_fitted(self)
#     105     X = self._check_X(X)
#     106     jll = self._joint_log_likelihood(X)
#
# File D:\program\conda\lib\site-packages\sklearn\utils\validation.py:1390, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1385     fitted = [
#    1386         v for v in vars(estimator) if v.endswith("_") and not v.startswith("__")
#    1387     ]
#    1389 if not fitted:
# -> 1390     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This GaussianNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
confusion=confusion_matrix(y_test,y_pred,labels=model.class_)
display=ConfusionMatrixDisplay(confusion_matrix=confusion,display_labels=model.classes_)
display.plot( )
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 confusion=confusion_matrix(y_test,y_pred,labels=model.class_)
#       2 display=ConfusionMatrixDisplay(confusion_matrix=confusion,display_labels=model.classes_)
#       3 display.plot( )
#
# NameError: name 'y_pred' is not defined
